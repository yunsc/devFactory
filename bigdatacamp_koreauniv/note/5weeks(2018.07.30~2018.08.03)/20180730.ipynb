# %% [markdown]
# # 0730 필기

# %%
import pandas as pd

# %%
pew = pd.read_csv('./data/pew.txt',sep='\t')

# %%
pew.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
melt_pew = pd.melt(pew, id_vars='religion')

# %%
melt_pew.head(10)
# Out:
#                   religion variable  value
# 0                 Agnostic    <$10k     27
# 1                  Atheist    <$10k     12
# 2                 Buddhist    <$10k     27
# 3                 Catholic    <$10k    418
# 4       Don’t know/refused    <$10k     15
# 5         Evangelical Prot    <$10k    575
# 6                    Hindu    <$10k      1
# 7  Historically Black Prot    <$10k    228
# 8        Jehovah's Witness    <$10k     20
# 9                   Jewish    <$10k     19

# %%
melt_pew = pd.melt(pew, id_vars='religion', var_name='income', value_name='count')

# %%
melt_pew.head(10)
# Out:
#                   religion income  count
# 0                 Agnostic  <$10k     27
# 1                  Atheist  <$10k     12
# 2                 Buddhist  <$10k     27
# 3                 Catholic  <$10k    418
# 4       Don’t know/refused  <$10k     15
# 5         Evangelical Prot  <$10k    575
# 6                    Hindu  <$10k      1
# 7  Historically Black Prot  <$10k    228
# 8        Jehovah's Witness  <$10k     20
# 9                   Jewish  <$10k     19

# %%
bil = pd.read_csv('./data/billboard.csv')

# %%
bil.head(10)
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# 5  2000                Janet                  Doesn't Really Matter  4:17
# 6  2000      Destiny's Child                            Say My Name  4:31
# 7  2000    Iglesias, Enrique                            Be With You  3:36
# 8  2000                Sisqo                             Incomplete  3:52
# 9  2000             Lonestar                                 Amazed  4:25
#
#      genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  \
# 0     Rock   2000-09-23  2000-11-18         78       63.0       49.0
# ...

# %%
ebola = pd.read_csv('./data/country_timeseries.csv')

# %%
ebola.head(10)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.2+ KB

# %%
ebola_long = pd.melt(ebola,id_vars=['Date','Day'])

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
'Case_Guinea'.split('_')
# Out:
# ['Case', 'Guinea']

# %%
variable_split = ebola_long['variable'].str.split('_')

# %%
type(variable_split)
# Out:
# pandas.core.series.Series

# %%
variable_split[1922][1]
# Out:
# 'Mali'

# %%
status_value = variable_split.str.get(0)
status_value.head()
# Out:
# 0    Cases
# 1    Cases
# 2    Cases
# 3    Cases
# 4    Cases
# Name: variable, dtype: object

# %%
nation_value = variable_split.str.get(1)
nation_value.head()
# Out:
# 0    Guinea
# 1    Guinea
# 2    Guinea
# 3    Guinea
# 4    Guinea
# Name: variable, dtype: object

# %%
ebola_long['status'] = status_value
ebola_long['nation'] = nation_value

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value status  nation
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea

# %% [markdown]
# ### 국가 별 통계 내보자. group by

# %%
ebola_long[ebola_long.status=='Deaths'].groupby('nation').mean()
# Out:
#                      Day        value
# nation
# Guinea        144.778689   563.239130
# Liberia       144.778689  1101.209877
# Mali          144.778689     3.166667
# Nigeria       144.778689     6.131579
# Senegal       144.778689     0.000000
# SierraLeone   144.778689   693.701149
# Spain         144.778689     0.187500
# UnitedStates  144.778689     0.833333

# %% [markdown]
# ----

# %%
weather = pd.read_csv('./data/weather.txt',sep='\t')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
weather_melt = weather.melt(['id','year','element','month'],var_name='day',value_name='temp')

# %%
weather_melt.head()
# Out:
#             id  year element  month day  temp
# 0  MX000017004  2010    TMAX      1  d1   NaN
# 1  MX000017004  2010    TMIN      1  d1   NaN
# 2  MX000017004  2010    TMAX      2  d1   NaN
# 3  MX000017004  2010    TMIN      2  d1   NaN
# 4  MX000017004  2010    TMAX      3  d1   NaN

# %%
weather_melt.dropna(inplace=True)

# %%
weather_melt.head()
# Out:
#              id  year element  month day   temp
# 20  MX000017004  2010    TMAX     12  d1  299.0
# 21  MX000017004  2010    TMIN     12  d1  138.0
# 24  MX000017004  2010    TMAX      2  d2  273.0
# 25  MX000017004  2010    TMIN      2  d2  144.0
# 40  MX000017004  2010    TMAX     11  d2  313.0

# %%
weather_tidy=weather_melt.pivot_table(
index=['id','year','month','day'],
columns = 'element',
values = 'temp')

# %%
weather_tidy.head()
# Out:
# element                      TMAX   TMIN
# id          year month day
# MX000017004 2010 1     d30  278.0  145.0
#                  2     d11  297.0  134.0
#                        d2   273.0  144.0
#                        d23  299.0  107.0
#                        d3   241.0  144.0

# %%
weather_tidy=(weather_melt.pivot_table(
    index=['id','year','month','day'],
    columns = 'element',
    values = 'temp')
  .reset_index()
)

# %%
weather_tidy.head()
# Out:
# element           id  year  month  day   TMAX   TMIN
# 0        MX000017004  2010      1  d30  278.0  145.0
# 1        MX000017004  2010      2  d11  297.0  134.0
# 2        MX000017004  2010      2   d2  273.0  144.0
# 3        MX000017004  2010      2  d23  299.0  107.0
# 4        MX000017004  2010      2   d3  241.0  144.0

# %% [markdown]
# -----

# %%
billboard = pd.read_csv('./data/billboard.csv')

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
billboard_melt = billboard.melt(['year','artist.inverted','track','time','genre','date.entered','date.peaked'], var_name='week')

# %%
billboard_melt.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked       week  value
# 0  Rock   2000-09-23  2000-11-18  x1st.week   78.0
# 1  Rock   2000-02-12  2000-04-08  x1st.week   15.0
# 2  Rock   1999-10-23  2000-01-29  x1st.week   71.0
# 3  Rock   2000-08-12  2000-09-16  x1st.week   41.0
# 4  Rock   2000-08-05  2000-10-14  x1st.week   57.0

# %%
billboard_melt.dropna(inplace=True)

# %%
billboard_melt.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked       week  value
# 0  Rock   2000-09-23  2000-11-18  x1st.week   78.0
# 1  Rock   2000-02-12  2000-04-08  x1st.week   15.0
# 2  Rock   1999-10-23  2000-01-29  x1st.week   71.0
# 3  Rock   2000-08-12  2000-09-16  x1st.week   41.0
# 4  Rock   2000-08-05  2000-10-14  x1st.week   57.0

# %%
billboard_melt.nsmallest(5,'value')
# Out:
#       year      artist.inverted              track  time genre date.entered  \
# 1588  2000              Madonna              Music  3:45  Rock   2000-08-12
# 1905  2000              Madonna              Music  3:45  Rock   2000-08-12
# 2222  2000              Madonna              Music  3:45  Rock   2000-08-12
# 2227  2000                Sisqo         Incomplete  3:52  Rock   2000-06-24
# 2230  2000  Aguilera, Christina  What A Girl Wants  3:18  Rock   1999-11-27
#
#      date.peaked       week  value
# 1588  2000-09-16  x6th.week    1.0
# 1905  2000-09-16  x7th.week    1.0
# 2222  2000-09-16  x8th.week    1.0
# 2227  2000-08-12  x8th.week    1.0
# 2230  2000-01-15  x8th.week    1.0

# %% [markdown]
# ----

# %% [markdown]
# # datetime

# %%
import datetime

# %% [markdown]
# ### 어 클래스네? 인스턴스화 해보자.

# %%
type(datetime.datetime)
# Out:
# type

# %%
a = datetime.datetime(2018,7,30)

# %%
a.year
# Out:
# 2018

# %%
a.strftime('%Y년 %A 요일'.encode('unicode-escape').decode()).encode().decode('unicode-escape')
# Out:
# '2018년 Monday 요일'

# %%
a.strftime('%y년 %A요일')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-161-9504954371a7> in <module>()
# ----> 1 a.strftime('%y년 %A요일')
#
# UnicodeEncodeError: 'locale' codec can't encode character '\ub144' in position 2: Illegal byte sequence

# %% [markdown]
# # numpy
# - 추가적인 기능도 지원해주고,
# - 더 속도가 빠르다.

# %%
import numpy as np
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
np.datetime64('2015-07-04')
# Out:
# numpy.datetime64('2015-07-04')

# %%
np.datetime64('2015-07-04 12:00')
# Out:
# numpy.datetime64('2015-07-04T12:00')

# %%
np.datetime64('2016-07-04 12:59:50','ns')
# Out:
# numpy.datetime64('2016-07-04T12:59:50.000000000')

# %% [markdown]
# # pandas

# %%
date = pd.to_datetime("12 8 2018")
date
# Out:
# Timestamp('2018-12-08 00:00:00')

# %%
date = pd.to_datetime("2018/07/30")
date
# Out:
# Timestamp('2018-07-30 00:00:00')

# %%
date.strftime("%A")
# Out:
# 'Monday'

# %%
date + pd.to_timedelta(-4,'W')
# Out:
# Timestamp('2018-07-02 00:00:00')

# %%
a = pd.Series([1,2,3,4],['a','b','c','d'])
a
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
index = pd.DatetimeIndex(['2014-07-04','2014-08-04','2015-04-03','2015-09-09'])

data = pd.Series([0,1,2,3], index = index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-04-03    2
# 2015-09-09    3
# dtype: int64

# %%
data['2015-04']
# Out:
# 2015-04-03    2
# dtype: int64

# %%
dates = pd.to_datetime([datetime.datetime(2015,8,3),"2018/07/30","2018/06/30","2018/05/30" ])
dates
# Out:
# DatetimeIndex(['2015-08-03', '2018-07-30', '2018-06-30', '2018-05-30'], dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-08-03', '2018-07-30', '2018-06-30', '2018-05-30'], dtype='period[D]', freq='D')

# %%
dates[0]
# Out:
# Timestamp('2015-08-03 00:00:00')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '1092 days', '1062 days', '1031 days'], dtype='timedelta64[ns]', freq=None)

# %% [markdown]
# ----

# %%
billboard = pd.read_csv('./data/billboard.csv')

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
temp_date = pd.to_datetime(billboard['date.entered'])

# %% [markdown]
# ### info() 로 데이터 타입이 변한 것을 확인할 수 있다.

# %%
billboard['date.entered'] = temp_date

# %%
pd.date_range('2018-07-02', periods=5, freq='M')
# Out:
# DatetimeIndex(['2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
#                '2018-11-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
import pandas as pd
import numpy as np
import datetime

# %%
date = datetime.date(year=2013, month=6, day=7)
time = datetime.time(hour=12, minute=30, second=19, microsecond=463198)
dt = datetime.datetime(year=2013, month=6, day=7, hour=12, minute=30, second=19, microsecond=463198)

# %%
dt
# Out:
# datetime.datetime(2013, 6, 7, 12, 30, 19, 463198)

# %%
td = datetime.timedelta(weeks=2, days=5, hours=10, minutes=20, seconds=6.73, milliseconds=99, microseconds=8)

# %%
td
# Out:
# datetime.timedelta(19, 37206, 829008)

# %%
date - td
# Out:
# datetime.date(2013, 5, 19)

# %%
from IPython import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity='all'

# %%
date - td
dt+td
# Out:
# datetime.date(2013, 5, 19)
# datetime.datetime(2013, 6, 26, 22, 50, 26, 292206)

# %%
pd.Timestamp('1/1/2018')
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
pd.Timestamp('22/1/2018')
# Out:
# Timestamp('2018-01-22 00:00:00')

# %%
pd.Timestamp('2014-5/10')
# Out:
# Timestamp('2014-05-10 00:00:00')

# %%
pd.Timestamp('Jan 3, 2018')
# Out:
# Timestamp('2018-01-03 00:00:00')

# %%
pd.Timestamp(5000, unit='D')
# Out:
# Timestamp('1983-09-10 00:00:00')

# %%
s = pd.Series([10,100,1000,10000])
b = pd.to_datetime(s, unit='D')
a = pd.Series(b)
a
# Out:
# 0   1970-01-11
# 1   1970-04-11
# 2   1972-09-27
# 3   1997-05-19
# dtype: datetime64[ns]

# %%
s = pd.Series(['12-5-2015','14-1-2013','20/12/2017','40/23/2017'])

# %%
pd.to_datetime(s, dayfirst=True, errors='coerce')
# Out:
# 0   2015-05-12
# 1   2013-01-14
# 2   2017-12-20
# 3          NaT
# dtype: datetime64[ns]

# %%
pd.Timedelta(days=5, minutes=7.34)
# Out:
# Timedelta('5 days 00:07:20.400000')

# %%
td1 = pd.to_timedelta([10,100],unit='s')
td2 = pd.to_timedelta(['3 hours','4 hours'])
td1 +td2
# Out:
# TimedeltaIndex(['03:00:10', '04:01:40'], dtype='timedelta64[ns]', freq=None)

# %%
td2
# Out:
# TimedeltaIndex(['03:00:00', '04:00:00'], dtype='timedelta64[ns]', freq=None)

# %%
td1
# Out:
# TimedeltaIndex(['00:00:10', '00:01:40'], dtype='timedelta64[ns]', freq=None)

# %%
ts = pd.Timestamp('2016-10-1 4:23:23.9')

# %%
ts
# Out:
# Timestamp('2016-10-01 04:23:23.900000')

# %%
type(ts)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
ts.ceil('h')
# Out:
# Timestamp('2016-10-01 05:00:00')

# %%
ts.year, ts.month, ts.day, ts.hour, ts.minute
# Out:
# (2016, 10, 1, 4, 23)

# %%
ts.dayofweek, ts.dayofyear, ts.daysinmonth
# Out:
# (5, 275, 31)

# %%
data_string_list = ['Sep 30 1894']*10000

# %%
pd.Timestamp('2016-10-1 4:23:23.9')
# Out:
# Timestamp('2016-10-01 04:23:23.900000')

# %% [markdown]
# ----

# %% [markdown]
# -----

# %%
crime = pd.read_hdf('./data/crime.h5')

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460911 entries, 0 to 460910
# Data columns (total 8 columns):
# OFFENSE_TYPE_ID        460911 non-null category
# OFFENSE_CATEGORY_ID    460911 non-null category
# REPORTED_DATE          460911 non-null datetime64[ns]
# GEO_LON                457296 non-null float64
# GEO_LAT                457296 non-null float64
# NEIGHBORHOOD_ID        460911 non-null category
# IS_CRIME               460911 non-null int64
# IS_TRAFFIC             460911 non-null int64
# dtypes: category(3), datetime64[ns](1), float64(2), int64(2)
# memory usage: 22.9 MB

# %%
crime.describe(include='all')
# Out:
#          OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID        GEO_LON        GEO_LAT  \
# count             460911              460911  457296.000000  457296.000000
# unique               196                  15            NaN            NaN
# top     traffic-accident    traffic-accident            NaN            NaN
# freq               87420              125060            NaN            NaN
# mean                 NaN                 NaN    -104.949973      39.726061
# std                  NaN                 NaN       1.243537       0.471636
# min                  NaN                 NaN    -105.300593       0.000001
# 25%                  NaN                 NaN    -105.009524      39.706890
# 50%                  NaN                 NaN    -104.982722      39.739285
# 75%                  NaN                 NaN    -104.929727      39.757689
# max                  NaN                 NaN      -0.000002      39.904311
#
#        NEIGHBORHOOD_ID       IS_CRIME     IS_TRAFFIC
# ...

# %%
type(crime)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 시계열은 시간/날짜를 인덱스로 사용한다.

# %%
crime = crime.set_index('REPORTED_DATE')
crime.head()
# Out:
#                                 OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00   traffic-accident-dui-duid    traffic-accident
# 2014-06-29 01:54:00  vehicular-eluding-no-chase    all-other-crimes
# 2014-06-29 02:00:00        disturbing-the-peace     public-disorder
# 2014-06-29 02:18:00                      curfew     public-disorder
# 2014-06-29 04:17:00          aggravated-assault  aggravated-assault
#
#                         GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00 -105.000149  39.745753                        cbd
# 2014-06-29 01:54:00 -104.884660  39.738702                east-colfax
# 2014-06-29 02:00:00 -105.020719  39.706674                athmar-park
# 2014-06-29 02:18:00 -105.001552  39.769505                  sunnyside
# 2014-06-29 04:17:00 -105.018557  39.679229  college-view-south-platte
#
#                      IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-06-29 02:01:00         0           1
# ...

# %%
crime.sort_index(inplace=True)

# %%
a = crime['2012-01-01':'2012-01-03']['IS_CRIME'].value_counts()[0]
b = crime['2012-01-01':'2012-01-03']['IS_CRIME'].value_counts()[1]
print('범죄율은', a/(a+b))
# Out:
# 범죄율은 0.42011834319526625

# %% [markdown]
# ### 바로 indexing 하는 것과 loc와 값은 같다. 하지만 혼동되니까 loc쓰자

# %%
crime.loc['2016-05-12']
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2016-05-12 00:05:00       public-order-crimes-other
# 2016-05-12 00:07:00                          curfew
# 2016-05-12 00:13:00                      traf-other
# 2016-05-12 00:33:00        police-false-information
# 2016-05-12 01:01:00          traf-habitual-offender
# 2016-05-12 01:05:00            criminal-trespassing
# 2016-05-12 01:14:00          theft-of-motor-vehicle
# 2016-05-12 01:18:00  violation-of-restraining-order
# 2016-05-12 01:26:00         criminal-mischief-other
# 2016-05-12 01:28:00                      traf-other
# 2016-05-12 01:34:00            criminal-trespassing
# 2016-05-12 01:34:00            disturbing-the-peace
# 2016-05-12 01:50:00                      traf-other
# 2016-05-12 01:52:00         criminal-mischief-other
# 2016-05-12 01:52:00                      assault-dv
# 2016-05-12 02:00:00            drug-cocaine-possess
# 2016-05-12 02:11:00               theft-of-services
# ...

# %%
crime['2016-05-12']
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2016-05-12 00:05:00       public-order-crimes-other
# 2016-05-12 00:07:00                          curfew
# 2016-05-12 00:13:00                      traf-other
# 2016-05-12 00:33:00        police-false-information
# 2016-05-12 01:01:00          traf-habitual-offender
# 2016-05-12 01:05:00            criminal-trespassing
# 2016-05-12 01:14:00          theft-of-motor-vehicle
# 2016-05-12 01:18:00  violation-of-restraining-order
# 2016-05-12 01:26:00         criminal-mischief-other
# 2016-05-12 01:28:00                      traf-other
# 2016-05-12 01:34:00            criminal-trespassing
# 2016-05-12 01:34:00            disturbing-the-peace
# 2016-05-12 01:50:00                      traf-other
# 2016-05-12 01:52:00         criminal-mischief-other
# 2016-05-12 01:52:00                      assault-dv
# 2016-05-12 02:00:00            drug-cocaine-possess
# 2016-05-12 02:11:00               theft-of-services
# ...

# %%
crime.loc['2015-12']['OFFENSE_CATEGORY_ID'].value_counts()
# Out:
# traffic-accident                1933
# all-other-crimes                1151
# public-disorder                  699
# larceny                          675
# theft-from-motor-vehicle         505
# burglary                         487
# auto-theft                       408
# drug-alcohol                     367
# other-crimes-against-persons     315
# aggravated-assault               140
# robbery                          102
# white-collar-crime                74
# sexual-assault                    44
# arson                              5
# murder                             2
# Name: OFFENSE_CATEGORY_ID, dtype: int64

# %% [markdown]
# ### index로 시간이 잡혀있으면 요런것도 가능! 하지만 우리는 이미 slicing 기법을 할 줄 아니까 상관없음

# %%
crime.between_time('2:00','5:00', include_end=False).head()
# Out:
#                                 OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 02:39:00          aggravated-assault            aggravated-assault
# 2012-01-02 03:30:00              assault-simple  other-crimes-against-persons
# 2012-01-02 04:07:00     criminal-mischief-other               public-disorder
# 2012-01-02 04:46:00              robbery-street                       robbery
# 2012-01-03 04:18:00  burglary-business-by-force                      burglary
#
#                         GEO_LON    GEO_LAT      NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2012-01-02 02:39:00 -105.001480  39.770655            sunnyside         1
# 2012-01-02 03:30:00 -104.876943  39.702783              windsor         1
# 2012-01-02 04:07:00 -104.905646  39.771597  northeast-park-hill         1
# 2012-01-02 04:46:00 -104.932636  39.730927                 hale         1
# 2012-01-03 04:18:00 -104.941613  39.783624       elyria-swansea         1
#
# ...

# %% [markdown]
# ### 7주 까지의 정보 출력

# %%
crime.first('7W')
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# 2012-01-02 02:39:00              aggravated-assault
# 2012-01-02 03:30:00                  assault-simple
# 2012-01-02 04:07:00         criminal-mischief-other
# 2012-01-02 04:46:00                  robbery-street
# 2012-01-02 06:52:00                traffic-accident
# 2012-01-02 09:07:00                traffic-accident
# 2012-01-02 09:42:00        theft-items-from-vehicle
# 2012-01-02 10:07:00                traffic-accident
# 2012-01-02 10:21:00                robbery-business
# 2012-01-02 10:55:00    traffic-accident-hit-and-run
# 2012-01-02 11:05:00              aggravated-assault
# 2012-01-02 11:32:00        theft-parts-from-vehicle
# ...

# %% [markdown]
# ----

# %% [markdown]
# ### 날짜 별로 그룹핑 해줌 resample
# - 사실 이게 제일중요함ㅋㅋ

# %%
weekly_crimes = crime.resample('W').size()

# %%
weekly_crimes.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %% [markdown]
# ### 그래프 그려보자.

# %%
weekly_crimes.plot()
